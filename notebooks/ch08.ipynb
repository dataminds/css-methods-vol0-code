# %% [markdown]
# # 8장 실습 · 가치와 선택 (선택적 노출·양극화)
#
# 이 노트북은 구글 **Colab**에서 바로 실행됩니다. 위에서부터 각 셀을 **Shift+Enter** 로 실행하세요.
# 설치도 로그인(구글 계정)만 있으면 됩니다. 서버에서 실행되므로 휴대폰에서도 잘 돌아갑니다.
#
# 📖 본문 학습 페이지: [8장 읽기](https://grow.minds.kr/textbooks/css-methods/vol0/book/ch08-가치와-선택.html)

# %% [markdown]
# ## 1. 실습 환경 준비
# 처음 한 번만, 보통 1분 안팎 걸립니다.

# %%
# 파이썬 행위자 모형 라이브러리 설치 + 이 책의 코드 내려받기
# !pip install -q mesa==3.3.1
# !git clone -q https://github.com/dataminds/css-methods-vol0-code.git
# %cd css-methods-vol0-code

# %% [markdown]
# ## 2. 모형 실행
# 아래 셀을 실행하면 이 장의 모형이 돌아가고 결과(서명)가 나옵니다.

# %%
# %run w08_thick_agent_softmax.py

# %% [markdown]
# ## 3. 결과 그림
# 그림이 있으면 아래에 표시됩니다(표로만 보는 장도 있습니다).

# %%
import glob
from IPython.display import Image, display
pngs = sorted(glob.glob('*.png'))
[display(Image(p)) for p in pngs] if pngs else print('이 장은 위의 표로 결과를 봅니다.')

# %% [markdown]
# ## 4. 직접 바꿔 보기
# 왼쪽 파일 탐색기(📁 아이콘)에서 **`w08_thick_agent_softmax.py`** 를 더블클릭해 열고, **tau(온도 모수)와 alpha(학습률)를** 바꾼 뒤 위의 `%run` 셀(2번)을 다시 실행하세요.
# 값에 따라 결과가 어떻게 달라지는지 보세요.
#
# > **검증 로그 (책 부록 B)**: 무엇을 바꿨고(예: eps=0.30), 무엇이 나왔고, 예상과 같았는지를 한 문단으로 적어 두세요. 실행이 아니라 *검증*이 이 책의 핵심입니다.
