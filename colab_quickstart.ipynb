# %% [markdown]
# # 계산으로 보는 사회 — 설치 없이 시작하기 (Google Colab)
#
# 이 노트북 하나로 책의 모든 실습 코드를 **설치 없이 브라우저에서** 돌릴 수 있습니다.
#
# **쓰는 법**: 아래 코드 칸(셀)을 위에서부터 하나씩 실행하세요. 셀 왼쪽의 ▶ 버튼을 누르거나, 셀을 클릭하고 Shift+Enter.
#
# 책(무료 웹판): https://grow.minds.kr/textbooks/css-methods/vol0/

# %% [markdown]
# ## 1단계 · 도구 상자 설치 (이 세션에만, 약 30초)

# %%
# %pip install -q mesa networkx numpy matplotlib
import mesa
print("준비 끝! mesa", mesa.__version__)

# %% [markdown]
# ## 2단계 · 실습 코드 가져오기

# %%
# !git clone -q https://github.com/dataminds/css-methods-vol0-code.git
# %cd css-methods-vol0-code
# !ls

# %% [markdown]
# ## 3단계 · 첫 모형 돌려 보기 (책 3장 · 경계신뢰)
#
# 실행하면 서명(eps별 군집 수)이 출력되고 그림 파일이 저장됩니다. 저장된 그림은 왼쪽 폴더 아이콘(파일 탐색기)에서 더블클릭해 볼 수 있습니다.

# %%
# %run w03_bounded_confidence.py

# %% [markdown]
# ## 다른 모형들도 같은 방법으로
#
# 아래 셀에서 원하는 줄의 맨 앞 `#`을 지우고 실행하세요.

# %%
# %run w02_bootcamp.py            # 1장 · 부트캠프
# %run w05_spiral_of_silence.py   # 5장 · 침묵의 나선
# %run w06_network_contagion.py   # 6장 · 네트워크 전염
# %run w08_thick_agent_softmax.py # 8장 · 선택적 노출
# %run w09_learning_agent.py      # 9장 · 예측오차 학습
# %run w10_time_varying_goal.py   # 10장 · 시변 목표
# %run w11_recovery_sensitivity.py# 11장 박스 · 모수 회복(선택)

# %% [markdown]
# ## 빈칸판으로 연습하기 (각 장 실습)
#
# 1. 왼쪽 파일 탐색기에서 `css-methods-vol0-code/blanks/` 폴더의 파일을 더블클릭해 연다.
# 2. `TODO` 블록을 채우고 `raise` 줄을 지운 뒤 저장(Ctrl+S).
# 3. 아래처럼 실행해 완성본과 서명을 대조한다.

# %%
# %run blanks/w03_bounded_confidence_blank.py

# %% [markdown]
# ## 직접 코드를 써 보기 (책 1장)
#
# 새 셀(+ 코드 버튼)을 만들어 자유롭게 실험하세요. 예:

# %%
import random
random.seed(73)                      # 이 책의 씨앗 규율: 우연이 낀 결과는 씨앗 없이 보고하지 않는다
position = 0
for step in range(5):
    coin = random.choice([1, -1])
    position = position + coin
    print(step, coin, position)

# %% [markdown]
# ---
# 막히면 오류 메시지를 통째로 생성 AI에게 붙여넣고 물어보세요(책 1장 · 표준 작업 절차). 제보: help@minds.kr
